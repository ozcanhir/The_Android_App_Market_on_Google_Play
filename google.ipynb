# %%
# Read in dataset
import pandas as pd
apps_with_duplicates =pd.read_csv(r"C:\Users\Pc\Desktop\Python_Project\The_Android_App_Market_on_Google_Play\apps.csv")

# Drop duplicates from apps_with_duplicates
apps = apps_with_duplicates.drop_duplicates() 

# Print the total number of apps
print('Total number of apps in the dataset = ', len(apps))

# Have a look at a random sample of 5 rows
apps.sample(n=5)
# Out:
# Total number of apps in the dataset =  9659
#       Unnamed: 0                                          App  \
# 614          743  edX - Online Courses by Harvard, MIT & more
# 2629        3358                              Golden Launcher
# 2207        2824                            Moto Photo Editor
# 2062        2609                Mirrativ: Live Stream Any App
# 5688        6719                                 Block Strike
#
#              Category  Rating  Reviews  Size     Installs  Type Price  \
# 614         EDUCATION     4.6    32381  10.0   1,000,000+  Free     0
# 2629  PERSONALIZATION     4.4    32794  12.0   5,000,000+  Free     0
# 2207      PHOTOGRAPHY     3.3     3492  17.0   5,000,000+  Free     0
# 2062           SOCIAL     4.1    17955  89.0     500,000+  Free     0
# 5688             GAME     4.5   947515  60.0  10,000,000+  Free     0
#
#      Content Rating           Genres    Last Updated Current Ver Android Ver
# 614    Everyone 10+        Education   July 15, 2018      2.15.1  4.1 and up
# 2629       Everyone  Personalization   July 31, 2018  1.284.1.83  4.2 and up
# 2207       Everyone      Photography   June 14, 2018     1.5.3.8  7.0 and up
# 2062           Teen           Social  August 2, 2018      7.23.4  4.1 and up
# 5688           Teen           Action   July 25, 2018       5.3.1  4.1 and up
